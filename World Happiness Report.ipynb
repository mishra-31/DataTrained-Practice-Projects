# %% [markdown]
# # World Happiness Report

# %% [markdown]
# ### Context
#
#
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more – describe how measurements of well-being can be used effectively to assess the progress of nations. The reports review the state of happiness in the world today and show how the new science of happiness explains personal and national variations in happiness.
#
#
# ### Content
#
#
# The happiness scores and rankings use data from the Gallup World Poll. The scores are based on answers to the main life evaluation question asked in the poll. This question, known as the Cantril ladder, asks respondents to think of a ladder with the best possible life for them being a 10 and the worst possible life being a 0 and to rate their own current lives on that scale. The scores are from nationally representative samples for the years 2013-2016 and use the Gallup weights to make the estimates representative. The columns following the happiness score estimate the extent to which each of six factors – economic production, social support, life expectancy, freedom, absence of corruption, and generosity – contribute to making life evaluations higher in each country than they are in Dystopia, a hypothetical country that has values equal to the world’s lowest national averages for each of the six factors. They have no impact on the total score reported for each country, but they do explain why some countries rank higher than others.
#
#
# #### What is Dystopia?
#
#
# Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared (no country performs more poorly than Dystopia) in terms of each of the six key variables, thus allowing each sub-bar to be of positive width. The lowest scores observed for the six key variables, therefore, characterize Dystopia. Since life would be very unpleasant in a country with the world’s lowest incomes, lowest life expectancy, lowest generosity, most corruption, least freedom and least social support, it is referred to as “Dystopia,” in contrast to Utopia.
#
#
# #### What are the residuals?
#
#
# The residuals, or unexplained components, differ for each country, reflecting the extent to which the six variables either over- or under-explain average 2014-2016 life evaluations. These residuals have an average value of approximately zero over the whole set of countries. Figure 2.2 shows the average residual for each country when the equation in Table 2.1 is applied to average 2014- 2016 data for the six variables in that country. We combine these residuals with the estimate for life evaluations in Dystopia so that the combined bar will always have positive values. As can be seen in Figure 2.2, although some life evaluation residuals are quite large, occasionally exceeding one point on the scale from 0 to 10, they are always much smaller than the calculated value in Dystopia, where the average life is rated at 1.85 on the 0 to 10 scale.

# %% [markdown]
# ### Importing important libraries

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")
print("setup complete")
# Out:
# setup complete

# %% [markdown]
# ### Loading the dataset

# %%
df = pd.read_csv("happiness_score_dataset.csv")
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
#checking shape of dataset
df.shape
# Out:
# (158, 12)

# %%
#checking information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
#checking column names in dataset
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
#checking information the column region for data analysis
df.Region.value_counts()
# Out:
# Sub-Saharan Africa                 40
# Central and Eastern Europe         29
# Latin America and Caribbean        22
# Western Europe                     21
# Middle East and Northern Africa    20
# Southeastern Asia                   9
# Southern Asia                       7
# Eastern Asia                        6
# North America                       2
# Australia and New Zealand           2
# Name: Region, dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# #### Univariate analysis

# %% [markdown]
# Checking distribution of different attributes

# %%
sns.distplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)', ylabel='Density'>

# %%
sns.distplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %%
sns.distplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)', ylabel='Density'>

# %%
sns.distplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom', ylabel='Density'>

# %%
sns.distplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %%
sns.distplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %%
sns.distplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual', ylabel='Density'>

# %% [markdown]
# Observation :
#
# - None of the plots are normally distributed all of them have a little bit of skewness.
#
# - Economy , Family , Health are left skewed whereas Freedom , Trust, Generosity, Dystopia Residual.

# %% [markdown]
# Checking outliers with the help of box plots for different attributes

# %%
sns.boxplot(df['Economy (GDP per Capita)'])
# Out:
# <AxesSubplot:xlabel='Economy (GDP per Capita)'>

# %%
sns.boxplot(df['Family'])
# Out:
# <AxesSubplot:xlabel='Family'>

# %%
sns.boxplot(df['Health (Life Expectancy)'])
# Out:
# <AxesSubplot:xlabel='Health (Life Expectancy)'>

# %%
sns.boxplot(df['Freedom'])
# Out:
# <AxesSubplot:xlabel='Freedom'>

# %%
sns.boxplot(df['Trust (Government Corruption)'])
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)'>

# %%
sns.boxplot(df['Generosity'])
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %%
sns.boxplot(df['Dystopia Residual'])
# Out:
# <AxesSubplot:xlabel='Dystopia Residual'>

# %% [markdown]
# Observation :
#
# In the above boxplots we can see that Family, Trust (Government Corruption), Generosity, Dystopia Residual have some outliers

# %% [markdown]
# #### Bivariate analysis

# %% [markdown]
# GDP vs Happiness score

# %%
plt.figure(figsize=(10,8))
plt.title('GDP vs Happiness Score',fontsize=15,y=1.1)
sns.scatterplot(df['Economy (GDP per Capita)'],df['Happiness Score'],data=df)
sns.set_style('darkgrid')
plt.show()

# %% [markdown]
# Observation :
#
# Countries with higher Economy(GDP) growth has higher happiness score i.e. people in these countries are happy.

# %% [markdown]
# Family vs Happiness Score

# %%
plt.figure(figsize=(10,8))
plt.title('Family vs Happiness Score',fontsize=15,y=1.1)
sns.scatterplot(df['Family'],df['Happiness Score'],data=df)
plt.show()

# %% [markdown]
# Observation :
#
# Countries with higher family score has higher happiness score i.e. people in these countries are happy.

# %% [markdown]
# Health vs Happiness Score

# %%
plt.figure(figsize=(10,8))
plt.title('Health vs Happiness Score',fontsize=15,y=1.1)
sns.scatterplot(df['Health (Life Expectancy)'],df['Happiness Score'],data=df)
plt.show()

# %% [markdown]
# Observation :
#
# Countries with higher health score has higher happiness score i.e. people in these countries are happy.

# %% [markdown]
# Freedom vs Happiness Score

# %%
plt.figure(figsize=(10,8))
plt.title('Freedom vs Happiness Score',fontsize=15,y=1.1)
sns.scatterplot(df['Freedom'],df['Happiness Score'],data=df)
plt.show()

# %% [markdown]
# Observation :
#
# There is not a very good linear relation between freedom and happiness score which means some countries although having high freedom score have less happiness score.

# %% [markdown]
# ### Happiness Score for each region

# %% [markdown]
# ##### European Countries

# %%
WesternEurope = df[df['Region'].isin(['Western Europe','Central and Eastern Europe'])]
plt.figure(figsize=[18,10])
sns.barplot(x='Country',y='Happiness Score',data=WesternEurope, hue='Region')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation :
#
# In European Region majorly Western European countries have high happiness score.

# %% [markdown]
# ##### American Countries

# %%
American_region = df[df.Region.isin(['North America', 'Latin America and Caribbean'])]
plt.figure(figsize=[12,9])
sns.barplot(x='Country',y='Happiness Score',data=American_region , hue='Region')
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation :
#
# In American Region Canada is the most happiest country

# %% [markdown]
# ##### Asian Countries

# %%
Asian_region = df[df.Region.isin(['Southeastern Asia', 'Southern Asia','Eastern Asia'])]
plt.figure(figsize=[12,9])
sns.barplot(x='Country',y='Happiness Score',data=Asian_region, hue='Region' )
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation :
#
# Southern Asian Countries have less happiness score as compared to South Eastern and Eastern region
# means Southern Asian has less happy people.

# %% [markdown]
# ##### African Countries

# %%
African_region = df[df.Region.isin(['Middle East and Northern Africa','Sub-Saharan Africa'])]
plt.figure(figsize=[12,9])
sns.barplot(x='Country',y='Happiness Score',data=African_region, hue='Region' )
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# Observation :
#
# Middle East and Northern African countries have high happiness score i.e. people are more happy in these regions of Africa.

# %%
#Pair plot
sns.pairplot(df,hue='Region')

# %% [markdown]
# #### Multivariate analysis

# %%
# checking corelation of the attributes
corelation = df.corr()
corelation
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
#Correlation heatmap
plt.figure(figsize=[12,9])
sns.heatmap(corelation, annot=True, linewidth = 2, linecolor='white')
plt.show()

# %% [markdown]
# Observation :
#
# - Economy, Family and Health are Highly positively correlated features with Happiness score.
#
# - Freedom and Dystopia Residual have about 50% postive correaltion with happiness score.
#
# - Trust (Government Corruption) is also a positvely correlated feature for happiness score.

# %% [markdown]
# ### Data Cleaning

# %%
# Checking for missing values
df2.isnull().sum()
# Out:
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
#checking data types of attributes
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %% [markdown]
# There are no missing values in the dataset

# %% [markdown]
# #### Outlier removal

# %%
#selecting attributes with numeric values
df2 = df.select_dtypes('float')
df2.head()
# Out:
#    Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0            7.587         0.03411                   1.39651  1.34951
# 1            7.561         0.04884                   1.30232  1.40223
# 2            7.527         0.03328                   1.32548  1.36058
# 3            7.522         0.03880                   1.45900  1.33095
# 4            7.427         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# 2                   0.87464  0.64938                        0.48357
# 3                   0.88521  0.66973                        0.36503
# 4                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# 0     0.29678            2.51738
# 1     0.43630            2.70201
# ...

# %%
#statistical summary of dataset
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
#calculating zscore of the dataset
from scipy.stats import zscore
z=zscore(df2)
df3=df.loc[(z<3).all(axis=1)] #selecting only those values which are not outliers

# %%
# checking shape of new data set without outliers
df3.shape
# Out:
# (152, 12)

# %% [markdown]
# #### Skewness

# %%
#checking skewness of the data
df3.skew()
# Out:
# Happiness Rank                  -0.002281
# Happiness Score                  0.104863
# Standard Error                   1.187230
# Economy (GDP per Capita)        -0.369427
# Family                          -1.028660
# Health (Life Expectancy)        -0.733022
# Freedom                         -0.393256
# Trust (Government Corruption)    1.285137
# Generosity                       0.655348
# Dystopia Residual               -0.192006
# dtype: float64

# %% [markdown]
# There is skewness in the data

# %%
#removing skewness from the data where skewness is greater than 5 or less than -5
for col in df2:
    if df3[col].skew()>=.5:
        df3[col]=np.sqrt(df3[col])
    if df3[col].skew()<=-0.5:
        df3[col]=np.power(df3[col],3)

# %%
#removed the skewness
df3.skew()
# Out:
# Happiness Rank                  -0.002281
# Happiness Score                  0.104863
# Standard Error                   0.671802
# Economy (GDP per Capita)        -0.369427
# Family                           0.158002
# Health (Life Expectancy)         0.447679
# Freedom                         -0.393256
# Trust (Government Corruption)    0.438262
# Generosity                      -0.276546
# Dystopia Residual               -0.192006
# dtype: float64

# %% [markdown]
# #### Label Encoding

# %%
#Encoding the categorical columns using label encoder
from sklearn.preprocessing import LabelEncoder

LE = LabelEncoder()
df3.Region = LE.fit_transform(df3.Region)
df3.Country = LE.fit_transform(df3.Country)
df3.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      130       9               1            7.587        0.184689
# 1       58       9               2            7.561        0.220998
# 2       37       9               3            7.527        0.182428
# 3      102       9               4            7.522        0.196977
# 4       24       5               5            7.427        0.188494
#
#    Economy (GDP per Capita)    Family  Health (Life Expectancy)  Freedom  \
# 0                   1.39651  2.457697                  0.834380  0.66557
# 1                   1.30232  2.757133                  0.851540  0.62877
# 2                   1.32548  2.518676                  0.669095  0.64938
# 3                   1.45900  2.357682                  0.693648  0.66973
# 4                   1.32629  2.313638                  0.742767  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# ...

# %%
#Dropping some features which have lots of different values
df4 = df3.drop(["Country","Happiness Rank"],axis=1)
df4.head()
# Out:
#    Region  Happiness Score  Standard Error  Economy (GDP per Capita)  \
# 0       9            7.587        0.184689                   1.39651
# 1       9            7.561        0.220998                   1.30232
# 2       9            7.527        0.182428                   1.32548
# 3       9            7.522        0.196977                   1.45900
# 4       5            7.427        0.188494                   1.32629
#
#      Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  2.457697                  0.834380  0.66557                       0.647904
# 1  2.757133                  0.851540  0.62877                       0.376098
# 2  2.518676                  0.669095  0.64938                       0.695392
# 3  2.357682                  0.693648  0.66973                       0.604177
# 4  2.313638                  0.742767  0.63297                       0.574082
#
#    Generosity  Dystopia Residual
# 0    0.544775            2.51738
# ...

# %% [markdown]
# #### Splitting the data into independent and dependent variables

# %%
#Feature variables
X = df4.drop("Happiness Score",axis=1)
X.head()
# Out:
#    Region  Standard Error  Economy (GDP per Capita)    Family  \
# 0       9        0.184689                   1.39651  2.457697
# 1       9        0.220998                   1.30232  2.757133
# 2       9        0.182428                   1.32548  2.518676
# 3       9        0.196977                   1.45900  2.357682
# 4       5        0.188494                   1.32629  2.313638
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                  0.834380  0.66557                       0.647904
# 1                  0.851540  0.62877                       0.376098
# 2                  0.669095  0.64938                       0.695392
# 3                  0.693648  0.66973                       0.604177
# 4                  0.742767  0.63297                       0.574082
#
#    Generosity  Dystopia Residual
# 0    0.544775            2.51738
# 1    0.660530            2.70201
# 2    0.584286            2.49204
# 3    0.589059            2.46531
# ...

# %%
#Target variable
y = df4["Happiness Score"]
y.head()
# Out:
# 0    7.587
# 1    7.561
# 2    7.527
# 3    7.522
# 4    7.427
# Name: Happiness Score, dtype: float64

# %% [markdown]
# #### Finding best random state

# %%
#importing train test split
from sklearn.model_selection import train_test_split

# %%
#checking best random state using decision tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
maxacc=0
maxrs=0
for i in range(1,200):
    xtrain, xtest, ytrain, ytest = train_test_split(X,y, test_size=0.3,random_state=i)
    mod = DecisionTreeRegressor()
    mod.fit(xtrain,ytrain)
    pred = mod.predict(xtest)
    acc = r2_score(ytest,pred)
    if acc>maxacc:
        maxacc = acc
        maxrs = i
print("Best accuracy is : ", maxacc, " best random state : ", maxrs)
# Out:
# Best accuracy is :  0.8532352559001354  best random state :  185

# %%
#splitting the data into training and testing sets
xtrain, xtest, ytrain, ytest = train_test_split(X,y, test_size=0.3,random_state=185)

# %%
#decision tree regressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score

DTR = DecisionTreeRegressor()
DTR.fit(xtrain,ytrain)
pred = DTR.predict(xtest)
print("R2 score",r2_score(ytest,pred))
# Out:
# R2 score 0.83284628866139

# %%
from sklearn.model_selection import cross_val_score
print("Cross validation score",cross_val_score(DTR,X,y,scoring='r2',cv=5).mean())
# Out:
# Cross validation score -7.906861089259823

# %%
#linear regression
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(xtrain,ytrain)
pred1 = lr.predict(xtest)
print("R2 score",r2_score(ytest,pred1))
# Out:
# R2 score 0.9807964884792298

# %%
print("Cross validation score",cross_val_score(lr,X,y,scoring='r2',cv=5).mean())
# Out:
# Cross validation score 0.6184281240128813

# %%
#Lasso regression
from sklearn.linear_model import Lasso
lasso=Lasso()
lasso.fit(xtrain,ytrain)
pred2 = lasso.predict(xtest)
print("R2 score",r2_score(ytest,pred2))
# Out:
# R2 score -0.0036650581472019717

# %%
print("Cross validation score",cross_val_score(lasso,X,y,scoring='r2',cv=5).mean())
# Out:
# Cross validation score -21.450884544631503

# %%
#k nearest neighbor regressor
from sklearn.neighbors import KNeighborsRegressor

k=2
knn = KNeighborsRegressor(n_neighbors=2)
knn.fit(xtrain,ytrain)
pred3 = knn.predict(xtest)
print("R2 score",r2_score(ytest,pred3))
# Out:
# R2 score 0.9059274632357882

# %%
print("Cross validation score",cross_val_score(knn,X,y,scoring='r2',cv=5).mean())
# Out:
# Cross validation score -6.789473013492781

# %%
#random forest regressor
from sklearn.ensemble import RandomForestRegressor

RTF = RandomForestRegressor()
RTF.fit(xtrain,ytrain)
pred4 = RTF.predict(xtest)
print("R2 score",r2_score(ytest,pred4))
# Out:
# R2 score 0.9288206175010413

# %%
print("Cross validation score",cross_val_score(RTF,X,y,scoring='r2',cv=5).mean())
# Out:
# Cross validation score -3.349818380683115

# %%
#support vector regressor
from sklearn.svm import SVR

svr = SVR()
svr.fit(xtrain,ytrain)
pred5 = svr.predict(xtest)
print("R2 score",r2_score(ytest,pred5))
# Out:
# R2 score 0.8983157078800851

# %%
print("Cross validation score",cross_val_score(svr,X,y,scoring='r2',cv=5).mean())
# Out:
# Cross validation score -2.145209312291946

# %%
#Ridge Regression
from sklearn.linear_model import Ridge

ridge = Ridge()
ridge.fit(xtrain,ytrain)
pred6 = ridge.predict(xtest)
print("R2 score",r2_score(ytest,pred6))
# Out:
# R2 score 0.9812977670944554

# %%
print("Cross validation score",cross_val_score(ridge,X,y,scoring='r2',cv=5).mean())
# Out:
# Cross validation score 0.49913379427250204

# %% [markdown]
# ### Linear Regression is the best model

# %%
#building final model
from sklearn.metrics import mean_absolute_error,mean_squared_error

final_model = LinearRegression()
final_model.fit(xtrain,ytrain)
prediction = final_model.predict(xtest)
print("R2 score",r2_score(ytest,prediction))
# Out:
# R2 score 0.9807964884792298

# %%
#Evaluating the model
print('MAE',mean_absolute_error(ytest,prediction))
print('MSE',mean_squared_error(ytest,prediction))
print('RMSE',np.sqrt(mean_squared_error(ytest,prediction)))
print('R2_score',r2_score(ytest,prediction))
# Out:
# MAE 0.1148771342157894
# MSE 0.03255360120311584
# RMSE 0.18042616551685578
# R2_score 0.9807964884792298

# %% [markdown]
# ## Saving the Model

# %%
#saving the model using joblib module
import joblib
joblib.dump(final_model,"FinalModel.pkl")
# Out:
# ['FinalModel.pkl']
